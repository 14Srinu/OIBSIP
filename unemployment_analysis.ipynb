# %%
from ast import increment_lineno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import calendar
import datetime as dt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
working_dir_path1="/content/drive/MyDrive/Colab Notebooks/Oasis Intern projects/Unemployment Analysis With Python/Unemployment in India.csv"
un_df1=pd.read_csv(working_dir_path1)

# %%
un_df1.head()

# %%
working_dir_path2="/content/drive/MyDrive/Colab Notebooks/Oasis Intern projects/Unemployment Analysis With Python/Unemployment_Rate_upto_11_2020.csv"
un_df2=pd.read_csv(working_dir_path2)

# %%
un_df1.tail()

# %%
un_df2.tail()

# %%
Open In Colab
Task-2

Project Name-Unemployment Analysis
Contributor-Navjot Khatri

Unemployment is measured by the unemployment rate which is the number of people who are unemployed as a percentage of the total labour force. We have seen a sharp increase in the unemployment rate during Covid-19

Context

The story behind this datasets is how lock-down affects employment opportunities and how the unemployment rate increases during the Covid-19.

Content

This dataset contains the unemployment rate of all the states in India

Region = states in India

Date = date which the unemployment rate observed

Frequency = measuring frequency (Monthly)

Estimated Unemployment Rate (%) = percentage of people unemployed in each States of India

Estimated Employed = percentage of people employed

Estimated Labour Participation Rate (%) = labour force participation rate by dividing the number of people actively participating in the labour force by the total number of people eligible to participate in the labor force force

questions?

How Covid-19 affects the employment

how far the unemployment rate will go

Importing Library

#import library
from ast import increment_lineno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


     

import calendar
import datetime as dt

     

#mount google drive
from google.colab import drive
drive.mount('/content/drive')
     
We Have Two Data sets 2019 and 2020. So we Analyze both Dataset And compare the Unemployment rate during these two years.

#reading csv file-1
working_dir_path1="/content/drive/MyDrive/Colab Notebooks/Oasis Intern projects/Unemployment Analysis With Python/Unemployment in India.csv"
un_df1=pd.read_csv(working_dir_path1)
     
Data Prepration

un_df1.head()
     
Region	Date	Frequency	Estimated Unemployment Rate (%)	Estimated Employed	Estimated Labour Participation Rate (%)	Area
0	Andhra Pradesh	31-05-2019	Monthly	3.65	11999139.0	43.24	Rural
1	Andhra Pradesh	30-06-2019	Monthly	3.05	11755881.0	42.05	Rural
2	Andhra Pradesh	31-07-2019	Monthly	3.75	12086707.0	43.50	Rural
3	Andhra Pradesh	31-08-2019	Monthly	3.32	12285693.0	43.97	Rural
4	Andhra Pradesh	30-09-2019	Monthly	5.17	12256762.0	44.68	Rural

#reading csv file-2
working_dir_path2="/content/drive/MyDrive/Colab Notebooks/Oasis Intern projects/Unemployment Analysis With Python/Unemployment_Rate_upto_11_2020.csv"
un_df2=pd.read_csv(working_dir_path2)
     

un_df2.head()
     
Region	Date	Frequency	Estimated Unemployment Rate (%)	Estimated Employed	Estimated Labour Participation Rate (%)	Region.1	longitude	latitude
0	Andhra Pradesh	31-01-2020	M	5.48	16635535	41.02	South	15.9129	79.74
1	Andhra Pradesh	29-02-2020	M	5.83	16545652	40.90	South	15.9129	79.74
2	Andhra Pradesh	31-03-2020	M	5.79	15881197	39.18	South	15.9129	79.74
3	Andhra Pradesh	30-04-2020	M	20.51	11336911	33.10	South	15.9129	79.74
4	Andhra Pradesh	31-05-2020	M	17.43	12988845	36.46	South	15.9129	79.74

un_df1.tail()
     
Region	Date	Frequency	Estimated Unemployment Rate (%)	Estimated Employed	Estimated Labour Participation Rate (%)	Area
763	NaN	NaN	NaN	NaN	NaN	NaN	NaN
764	NaN	NaN	NaN	NaN	NaN	NaN	NaN
765	NaN	NaN	NaN	NaN	NaN	NaN	NaN
766	NaN	NaN	NaN	NaN	NaN	NaN	NaN
767	NaN	NaN	NaN	NaN	NaN	NaN	NaN

un_df2.tail()
     
Region	Date	Frequency	Estimated Unemployment Rate (%)	Estimated Employed	Estimated Labour Participation Rate (%)	Region.1	longitude	latitude
262	West Bengal	30-06-2020	M	7.29	30726310	40.39	East	22.9868	87.855
263	West Bengal	31-07-2020	M	6.83	35372506	46.17	East	22.9868	87.855
264	West Bengal	31-08-2020	M	14.87	33298644	47.48	East	22.9868	87.855
265	West Bengal	30-09-2020	M	9.35	35707239	47.73	East	22.9868	87.855
266	West Bengal	31-10-2020	M	9.98	33962549	45.63	East	22.9868	87.855

un_df1.shape
     
(768, 7)

un_df2.shape
     
(267, 9)

un_df1.describe()
     
Estimated Unemployment Rate (%)	Estimated Employed	Estimated Labour Participation Rate (%)
count	740.000000	7.400000e+02	740.000000
mean	11.787946	7.204460e+06	42.630122
std	10.721298	8.087988e+06	8.111094
min	0.000000	4.942000e+04	13.330000
25%	4.657500	1.190404e+06	38.062500
50%	8.350000	4.744178e+06	41.160000
75%	15.887500	1.127549e+07	45.505000
max	76.740000	4.577751e+07	72.570000

un_df2.describe()
     
Estimated Unemployment Rate (%)	Estimated Employed	Estimated Labour Participation Rate (%)	longitude	latitude
count	267.000000	2.670000e+02	267.000000	267.000000	267.000000
mean	12.236929	1.396211e+07	41.681573	22.826048	80.532425
std	10.803283	1.336632e+07	7.845419	6.270731	5.831738
min	0.500000	1.175420e+05	16.770000	10.850500	71.192400
25%	4.845000	2.838930e+06	37.265000	18.112400	76.085600
50%	9.650000	9.732417e+06	40.390000	23.610200	79.019300
75%	16.755000	2.187869e+07	44.055000	27.278400	85.279900
max	75.850000	5.943376e+07	69.690000	33.778200	92.937600

un_df1.info()
     
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 768 entries, 0 to 767
Data columns (total 7 columns):
 #   Column                                    Non-Null Count  Dtype  
---  ------                                    --------------  -----  
 0   Region                                    740 non-null    object 
 1    Date                                     740 non-null    object 
 2    Frequency                                740 non-null    object 
 3    Estimated Unemployment Rate (%)          740 non-null    float64
 4    Estimated Employed                       740 non-null    float64
 5    Estimated Labour Participation Rate (%)  740 non-null    float64
 6   Area                                      740 non-null    object 
dtypes: float64(3), object(4)
memory usage: 42.1+ KB

un_df2.info()
     
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 267 entries, 0 to 266
Data columns (total 9 columns):
 #   Column                                    Non-Null Count  Dtype  
---  ------                                    --------------  -----  
 0   Region                                    267 non-null    object 
 1    Date                                     267 non-null    object 
 2    Frequency                                267 non-null    object 
 3    Estimated Unemployment Rate (%)          267 non-null    float64
 4    Estimated Employed                       267 non-null    int64  
 5    Estimated Labour Participation Rate (%)  267 non-null    float64
 6   Region.1                                  267 non-null    object 
 7   longitude                                 267 non-null    float64
 8   latitude                                  267 non-null    float64
dtypes: float64(4), int64(1), object(4)
memory usage: 18.9+ KB

un_df1.isnull().sum()
     
Region                                      28
 Date                                       28
 Frequency                                  28
 Estimated Unemployment Rate (%)            28
 Estimated Employed                         28
 Estimated Labour Participation Rate (%)    28
Area                                        28
dtype: int64

un_df2.isnull().sum()
     
Region                                      0
 Date                                       0
 Frequency                                  0
 Estimated Unemployment Rate (%)            0
 Estimated Employed                         0
 Estimated Labour Participation Rate (%)    0
Region.1                                    0
longitude                                   0
latitude                                    0
dtype: int64
Data Cleaning

un_df1=un_df1.dropna()
     

un_df1.isnull().sum()
     
Region                                      0
 Date                                       0
 Frequency                                  0
 Estimated Unemployment Rate (%)            0
 Estimated Employed                         0
 Estimated Labour Participation Rate (%)    0
Area                                        0
dtype: int64

un_df1.columns =['States','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Region']
     

un_df2.columns =['States','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Region','longitude','latitude']
     

un_df1['Frequency']= un_df1['Frequency'].astype('category')
     

un_df2['Frequency']= un_df2['Frequency'].astype('category')
     

un_df1['Date'] = pd.to_datetime(un_df1['Date'],dayfirst=True)
     

un_df2['Date'] = pd.to_datetime(un_df2['Date'],dayfirst=True)
     

un_df1.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region
0	Andhra Pradesh	2019-05-31	Monthly	3.65	11999139.0	43.24	Rural
1	Andhra Pradesh	2019-06-30	Monthly	3.05	11755881.0	42.05	Rural
2	Andhra Pradesh	2019-07-31	Monthly	3.75	12086707.0	43.50	Rural
3	Andhra Pradesh	2019-08-31	Monthly	3.32	12285693.0	43.97	Rural
4	Andhra Pradesh	2019-09-30	Monthly	5.17	12256762.0	44.68	Rural

un_df2.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude
0	Andhra Pradesh	2020-01-31	M	5.48	16635535	41.02	South	15.9129	79.74
1	Andhra Pradesh	2020-02-29	M	5.83	16545652	40.90	South	15.9129	79.74
2	Andhra Pradesh	2020-03-31	M	5.79	15881197	39.18	South	15.9129	79.74
3	Andhra Pradesh	2020-04-30	M	20.51	11336911	33.10	South	15.9129	79.74
4	Andhra Pradesh	2020-05-31	M	17.43	12988845	36.46	South	15.9129	79.74

un_df1['Month'] = un_df1['Date'].dt.month
     

un_df2['Month'] = un_df2['Date'].dt.month
     

un_df2.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude	Month
0	Andhra Pradesh	2020-01-31	M	5.48	16635535	41.02	South	15.9129	79.74	1
1	Andhra Pradesh	2020-02-29	M	5.83	16545652	40.90	South	15.9129	79.74	2
2	Andhra Pradesh	2020-03-31	M	5.79	15881197	39.18	South	15.9129	79.74	3
3	Andhra Pradesh	2020-04-30	M	20.51	11336911	33.10	South	15.9129	79.74	4
4	Andhra Pradesh	2020-05-31	M	17.43	12988845	36.46	South	15.9129	79.74	5

un_df1['Month_int'] =un_df1['Month'].apply(lambda x : int(x))
un_df2['Month_int'] =un_df2['Month'].apply(lambda x : int(x))
     

un_df1['Month_name'] =un_df1['Month_int'].apply(lambda x: calendar.month_abbr[x])
un_df2['Month_name'] =un_df2['Month_int'].apply(lambda x: calendar.month_abbr[x])
     

un_df2.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude	Month	Month_int	Month_name
0	Andhra Pradesh	2020-01-31	M	5.48	16635535	41.02	South	15.9129	79.74	1	1	Jan
1	Andhra Pradesh	2020-02-29	M	5.83	16545652	40.90	South	15.9129	79.74	2	2	Feb
2	Andhra Pradesh	2020-03-31	M	5.79	15881197	39.18	South	15.9129	79.74	3	3	Mar
3	Andhra Pradesh	2020-04-30	M	20.51	11336911	33.10	South	15.9129	79.74	4	4	Apr
4	Andhra Pradesh	2020-05-31	M	17.43	12988845	36.46	South	15.9129	79.74	5	5	May

un_df1['Region'] = un_df1['Region'].astype('category')
un_df2['Region'] = un_df2['Region'].astype('category')
     

un_df1.drop(columns='Month',inplace=True)
un_df2.drop(columns='Month',inplace=True)
     

un_df1.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	Month_int	Month_name
0	Andhra Pradesh	2019-05-31	Monthly	3.65	11999139.0	43.24	Rural	5	May
1	Andhra Pradesh	2019-06-30	Monthly	3.05	11755881.0	42.05	Rural	6	Jun
2	Andhra Pradesh	2019-07-31	Monthly	3.75	12086707.0	43.50	Rural	7	Jul
3	Andhra Pradesh	2019-08-31	Monthly	3.32	12285693.0	43.97	Rural	8	Aug
4	Andhra Pradesh	2019-09-30	Monthly	5.17	12256762.0	44.68	Rural	9	Sep

un_df1.tail()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	Month_int	Month_name
749	West Bengal	2020-02-29	Monthly	7.55	10871168.0	44.09	Urban	2	Feb
750	West Bengal	2020-03-31	Monthly	6.67	10806105.0	43.34	Urban	3	Mar
751	West Bengal	2020-04-30	Monthly	15.63	9299466.0	41.20	Urban	4	Apr
752	West Bengal	2020-05-31	Monthly	15.22	9240903.0	40.67	Urban	5	May
753	West Bengal	2020-06-30	Monthly	9.86	9088931.0	37.57	Urban	6	Jun

un_df2.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude	Month_int	Month_name
0	Andhra Pradesh	2020-01-31	M	5.48	16635535	41.02	South	15.9129	79.74	1	Jan
1	Andhra Pradesh	2020-02-29	M	5.83	16545652	40.90	South	15.9129	79.74	2	Feb
2	Andhra Pradesh	2020-03-31	M	5.79	15881197	39.18	South	15.9129	79.74	3	Mar
3	Andhra Pradesh	2020-04-30	M	20.51	11336911	33.10	South	15.9129	79.74	4	Apr
4	Andhra Pradesh	2020-05-31	M	17.43	12988845	36.46	South	15.9129	79.74	5	May

un_df2.tail()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude	Month_int	Month_name
262	West Bengal	2020-06-30	M	7.29	30726310	40.39	East	22.9868	87.855	6	Jun
263	West Bengal	2020-07-31	M	6.83	35372506	46.17	East	22.9868	87.855	7	Jul
264	West Bengal	2020-08-31	M	14.87	33298644	47.48	East	22.9868	87.855	8	Aug
265	West Bengal	2020-09-30	M	9.35	35707239	47.73	East	22.9868	87.855	9	Sep
266	West Bengal	2020-10-31	M	9.98	33962549	45.63	East	22.9868	87.855	10	Oct
We Split our Dataset into two parts one of them before the lockdown[2019-5 to 2020-3] And the Second One during Lockdown[2020-4 to 2020-10].

mask = (un_df1['Date'] >= '2019-05-31') & (un_df1['Date'] <= '2020-03-31')
df1 = un_df1.loc[mask]
     

df1
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	Month_int	Month_name
0	Andhra Pradesh	2019-05-31	Monthly	3.65	11999139.0	43.24	Rural	5	May
1	Andhra Pradesh	2019-06-30	Monthly	3.05	11755881.0	42.05	Rural	6	Jun
2	Andhra Pradesh	2019-07-31	Monthly	3.75	12086707.0	43.50	Rural	7	Jul
3	Andhra Pradesh	2019-08-31	Monthly	3.32	12285693.0	43.97	Rural	8	Aug
4	Andhra Pradesh	2019-09-30	Monthly	5.17	12256762.0	44.68	Rural	9	Sep
...	...	...	...	...	...	...	...	...	...
746	West Bengal	2019-11-30	Monthly	6.61	10768462.0	43.44	Urban	11	Nov
747	West Bengal	2019-12-31	Monthly	7.24	11335696.0	45.97	Urban	12	Dec
748	West Bengal	2020-01-31	Monthly	7.27	11208617.0	45.39	Urban	1	Jan
749	West Bengal	2020-02-29	Monthly	7.55	10871168.0	44.09	Urban	2	Feb
750	West Bengal	2020-03-31	Monthly	6.67	10806105.0	43.34	Urban	3	Mar
588 rows × 9 columns


mask = (un_df2['Date'] >= '2020-04-30')
df2 = un_df2.loc[mask]
     

df2
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude	Month_int	Month_name
3	Andhra Pradesh	2020-04-30	M	20.51	11336911	33.10	South	15.9129	79.740	4	Apr
4	Andhra Pradesh	2020-05-31	M	17.43	12988845	36.46	South	15.9129	79.740	5	May
5	Andhra Pradesh	2020-06-30	M	3.31	19805400	47.41	South	15.9129	79.740	6	Jun
6	Andhra Pradesh	2020-07-31	M	8.34	15431615	38.91	South	15.9129	79.740	7	Jul
7	Andhra Pradesh	2020-08-31	M	6.96	15251776	37.83	South	15.9129	79.740	8	Aug
...	...	...	...	...	...	...	...	...	...	...	...
262	West Bengal	2020-06-30	M	7.29	30726310	40.39	East	22.9868	87.855	6	Jun
263	West Bengal	2020-07-31	M	6.83	35372506	46.17	East	22.9868	87.855	7	Jul
264	West Bengal	2020-08-31	M	14.87	33298644	47.48	East	22.9868	87.855	8	Aug
265	West Bengal	2020-09-30	M	9.35	35707239	47.73	East	22.9868	87.855	9	Sep
266	West Bengal	2020-10-31	M	9.98	33962549	45.63	East	22.9868	87.855	10	Oct
188 rows × 11 columns


df1["States"].unique()
     
array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
       'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
       'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
       'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
       'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
       'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
      dtype=object)

df2["States"].unique()
     
array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
       'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
       'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
       'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
       'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
       'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

undf_stats1 = df1[['Estimated Unemployment Rate','Estimated Employed', 'Estimated Labour Participation Rate']]

undf_stats2 = df2[['Estimated Unemployment Rate','Estimated Employed', 'Estimated Labour Participation Rate']]
     

undf_stats1.head()

     
Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
0	3.65	11999139.0	43.24
1	3.05	11755881.0	42.05
2	3.75	12086707.0	43.50
3	3.32	12285693.0	43.97
4	5.17	12256762.0	44.68

undf_stats2.head()
     
Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
3	20.51	11336911	33.10
4	17.43	12988845	36.46
5	3.31	19805400	47.41
6	8.34	15431615	38.91
7	6.96	15251776	37.83

undf_stats1.describe()
     
Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
count	588.000000	5.880000e+02	588.000000
mean	9.614864	7.470499e+06	43.815187
std	7.372715	8.276125e+06	7.679054
min	0.000000	8.618600e+04	26.330000
25%	4.332500	1.190404e+06	39.047500
50%	7.225000	5.064048e+06	42.330000
75%	13.300000	1.164705e+07	45.897500
max	34.690000	4.577751e+07	72.570000

undf_stats2.describe()
     
Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
count	188.000000	1.880000e+02	188.000000
mean	13.277128	1.343658e+07	40.632074
std	11.805614	1.307267e+07	7.395797
min	0.500000	1.175420e+05	16.770000
25%	5.037500	2.719468e+06	36.317500
50%	10.525000	9.358904e+06	39.625000
75%	17.415000	2.004234e+07	43.092500
max	75.850000	5.653952e+07	64.600000

round(undf_stats1.describe().T,2)
     
count	mean	std	min	25%	50%	75%	max
Estimated Unemployment Rate	588.0	9.61	7.37	0.00	4.33	7.22	13.30	34.69
Estimated Employed	588.0	7470498.57	8276124.71	86186.00	1190404.50	5064048.50	11647054.75	45777509.00
Estimated Labour Participation Rate	588.0	43.82	7.68	26.33	39.05	42.33	45.90	72.57

round(undf_stats2.describe().T,2)
     
count	mean	std	min	25%	50%	75%	max
Estimated Unemployment Rate	188.0	13.28	11.81	0.50	5.04	10.52	17.42	75.85
Estimated Employed	188.0	13436576.06	13072671.59	117542.00	2719468.25	9358904.50	20042339.00	56539521.00
Estimated Labour Participation Rate	188.0	40.63	7.40	16.77	36.32	39.62	43.09	64.60

region_stats1 = df1.groupby(['Region'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean().reset_index()

     

region_stats1 = round(region_stats1,2)
     

region_stats1
     
Region	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
0	Rural	8.23	10580891.91	45.52
1	Urban	10.91	4564736.36	42.23

region_stats2 = df2.groupby(['Region'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean().reset_index()

     

region_stats2 = round(region_stats2,2)
     

region_stats2
     
Region	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
0	East	16.17	18801824.50	39.32
1	North	16.23	12817156.05	37.67
2	Northeast	10.03	3342133.89	49.33
3	South	12.98	13441439.90	39.45
4	West	9.27	18187468.74	40.79
Data Visualizations

plt.figure(figsize=(25,8))

plt.subplot(1,2,1)
plt.title("co-relations of variables Before Lockdown", fontsize=16)
sns.heatmap(undf_stats1.corr(), annot=True, linewidths=0.1, fmt='.2f', square=True)

plt.subplot(1,2,2)
plt.title("co-relations of variables During Lockdown", fontsize=16)
sns.heatmap(undf_stats2.corr(), annot=True, linewidths=0.1, fmt='.2f', square=True)

plt.show()
     


plt.figure(figsize=(25, 8))

plt.subplot(1,2,1)
sns.barplot(x='Region', y='Estimated Unemployment Rate', data=df1)
plt.xlabel("Region",fontsize=16)
plt.ylabel('Estimated Unemployment Rate',fontsize=16)
plt.title('Estimated Unemployment Rate Before Lockdown',fontsize=16)



plt.subplot(1,2,2)
sns.barplot(x='Region', y='Estimated Unemployment Rate', data=df2)
plt.xlabel("Region",fontsize=16)
plt.ylabel('Estimated Unemployment Rate',fontsize=16)
plt.title('Estimated Unemployment Rate During Lockdown',fontsize=16)


plt.show()
     


plt.figure(figsize=(25,8))

plt.subplot(1,2,1)
plt.title("State Wise Estimated Unemployment Rate Before Lockdown",fontsize=16)
sns.boxplot(y="States",x ='Estimated Unemployment Rate',data =df1)
plt.xlabel("Estimated Unemployment Rate",fontsize=16)
plt.ylabel("States",fontsize=16)

plt.subplot(1,2,2)
plt.title("State Wise Estimated Unemployment Rate During Lockdown",fontsize=16)
sns.boxplot(y="States",x ='Estimated Unemployment Rate',data =df2)
plt.xlabel("Estimated Unemployment Rate",fontsize=16)
plt.ylabel("States",fontsize=16)

plt.show()
     


df1.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	Month_int	Month_name
0	Andhra Pradesh	2019-05-31	Monthly	3.65	11999139.0	43.24	Rural	5	May
1	Andhra Pradesh	2019-06-30	Monthly	3.05	11755881.0	42.05	Rural	6	Jun
2	Andhra Pradesh	2019-07-31	Monthly	3.75	12086707.0	43.50	Rural	7	Jul
3	Andhra Pradesh	2019-08-31	Monthly	3.32	12285693.0	43.97	Rural	8	Aug
4	Andhra Pradesh	2019-09-30	Monthly	5.17	12256762.0	44.68	Rural	9	Sep

df2.head()
     
States	Date	Frequency	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	Region	longitude	latitude	Month_int	Month_name
3	Andhra Pradesh	2020-04-30	M	20.51	11336911	33.10	South	15.9129	79.74	4	Apr
4	Andhra Pradesh	2020-05-31	M	17.43	12988845	36.46	South	15.9129	79.74	5	May
5	Andhra Pradesh	2020-06-30	M	3.31	19805400	47.41	South	15.9129	79.74	6	Jun
6	Andhra Pradesh	2020-07-31	M	8.34	15431615	38.91	South	15.9129	79.74	7	Jul
7	Andhra Pradesh	2020-08-31	M	6.96	15251776	37.83	South	15.9129	79.74	8	Aug

States_stats1 = df1.groupby(['States'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean().reset_index()
     

States_stats1.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
0	Andhra Pradesh	5.213182	8.340685e+06	39.877273
1	Assam	6.437619	5.585966e+06	45.999048
2	Bihar	13.990000	1.319102e+07	38.447727
3	Chandigarh	16.789091	3.177700e+05	39.840000
4	Chhattisgarh	7.711364	4.490173e+06	45.060909

States_stats1.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
0	Andhra Pradesh	5.213182	8.340685e+06	39.877273
1	Assam	6.437619	5.585966e+06	45.999048
2	Bihar	13.990000	1.319102e+07	38.447727
3	Chandigarh	16.789091	3.177700e+05	39.840000
4	Chhattisgarh	7.711364	4.490173e+06	45.060909

States_stats1.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
0	Andhra Pradesh	5.213182	8.340685e+06	39.877273
1	Assam	6.437619	5.585966e+06	45.999048
2	Bihar	13.990000	1.319102e+07	38.447727
3	Chandigarh	16.789091	3.177700e+05	39.840000
4	Chhattisgarh	7.711364	4.490173e+06	45.060909

States_stats2 = df2.groupby(['States'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','longitude','latitude']].mean().reset_index()
     

States_stats2.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	longitude	latitude
0	Andhra Pradesh	9.934286	1.502749e+07	38.360000	15.9129	79.7400
1	Assam	4.960000	1.048853e+07	42.071429	26.2006	92.9376
2	Bihar	22.625714	2.252449e+07	36.852857	25.0961	85.3131
3	Chhattisgarh	7.517143	8.166270e+06	39.622857	21.2787	81.8661
4	Delhi	18.575714	4.158975e+06	32.030000	28.7041	77.1025

States_stats2=round(States_stats2,2)
     

States_stats2.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	longitude	latitude
0	Andhra Pradesh	9.93	15027488.00	38.36	15.91	79.74
1	Assam	4.96	10488527.86	42.07	26.20	92.94
2	Bihar	22.63	22524490.71	36.85	25.10	85.31
3	Chhattisgarh	7.52	8166269.86	39.62	21.28	81.87
4	Delhi	18.58	4158974.71	32.03	28.70	77.10

States_stats1 = round(States_stats1,2)
     

States_stats1=States_stats1.sort_values(by='Estimated Unemployment Rate', ascending=False)
     

States_stats2=States_stats2.sort_values(by='Estimated Unemployment Rate', ascending=False)
     

States_stats2.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	longitude	latitude
7	Haryana	29.09	6683266.00	41.97	29.06	76.09
17	Puducherry	25.13	325670.00	35.20	11.94	79.81
10	Jharkhand	23.53	8206407.86	39.56	23.61	85.28
23	Tripura	22.79	1338411.86	53.31	23.94	91.99
2	Bihar	22.63	22524490.71	36.85	25.10	85.31

plt.figure(figsize=(25,8))


plt.subplot(1,2,1)
plt.title("Estimated Unemployment Rate Before Lockdown",fontsize=16)
sns.barplot(data=States_stats1,x="States",y="Estimated Unemployment Rate")
plt.xticks(rotation= 90)
plt.xlabel('States',fontsize=16)
plt.ylabel('Estimated Unemployment Rate',fontsize=16)


plt.subplot(1,2,2)
plt.title("Estimated Unemployment Rate During Lockdown",fontsize=16)
sns.barplot(data=States_stats2,x="States",y="Estimated Unemployment Rate")
plt.xticks(rotation= 90)
plt.xlabel('States',fontsize=16)
plt.ylabel('Estimated Unemployment Rate',fontsize=16)


plt.show()
     

Top Five State Were Estimated Unemployment Rate Highest Before Lockdown

Tripura 28.98

Haryana 23.17

Himachal Pradesh 19.40

Jammu & Kashmir 16.99

Chandigarh 16.79

Top Five State Were Estimated Unemployment Rate Highest During Lockdown

Haryana 29.09

Puducherry 25.13

Jharkhand 23.53

Tripura 22.79

Bihar 22.63


estimated_employed1=States_stats1.sort_values(by='Estimated Employed', ascending=False)

estimated_employed2=States_stats2.sort_values(by='Estimated Employed', ascending=False)
     

plt.figure(figsize=(25,8))


plt.subplot(1,2,1)
plt.title("Estimated Employed workforce Before Lockdown",fontsize=16)
sns.barplot(data=estimated_employed1,x="States",y="Estimated Employed")
plt.xticks(rotation= 90)
plt.xlabel('States',fontsize=16)
plt.ylabel('Estimated Employed',fontsize=16)


plt.subplot(1,2,2)
plt.title("Estimated Employed Workforce During Lockdown",fontsize=16)
sns.barplot(data=estimated_employed2,x="States",y="Estimated Employed")
plt.xticks(rotation= 90)
plt.xlabel('States',fontsize=16)
plt.ylabel('Estimated Employed',fontsize=16)


plt.show()
     


estimated_employed1.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
25	Uttar Pradesh	10.64	28675914.86	39.65
15	Maharashtra	5.41	20976060.18	43.60
27	West Bengal	6.60	17997669.77	46.82
22	Tamil Nadu	3.16	13837079.95	44.08
2	Bihar	13.99	13191022.05	38.45

estimated_employed2.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	longitude	latitude
24	Uttar Pradesh	10.10	54396766.00	36.90	26.85	80.95
14	Maharashtra	9.19	38119655.86	40.68	19.75	75.71
26	West Bengal	11.88	32051822.71	44.17	22.99	87.86
2	Bihar	22.63	22524490.71	36.85	25.10	85.31
6	Gujarat	6.45	22122382.71	44.08	22.26	71.19
Top Five State Were Maximum Estimated Employed Workforce Before Lockdown

Uttar Pradesh 28675914.86
Maharashtra 20976060.18
West Bengal 17997669.77
Tamil Nadu 13837079.95
Bihar 13191022.05
Top Five State Were Maximum Estimated Employed Workforce During Lockdown

Uttar Pradesh 54396766.00
Maharashtra 38119655.86
West Bengal 32051822.71
Bihar 22524490.71
Gujarat 22122382.71

Estimated_Labour_Participation_Rate1=States_stats1.sort_values(by='Estimated Labour Participation Rate', ascending=False)

Estimated_Labour_Participation_Rate2=States_stats2.sort_values(by='Estimated Labour Participation Rate', ascending=False)
     

Estimated_Labour_Participation_Rate1.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate
24	Tripura	28.98	741353.59	64.53
16	Meghalaya	3.82	695116.95	58.43
23	Telangana	4.77	8456889.73	55.01
21	Sikkim	7.44	109052.50	48.64
7	Gujarat	5.30	11952497.59	47.91

Estimated_Labour_Participation_Rate2.head()
     
States	Estimated Unemployment Rate	Estimated Employed	Estimated Labour Participation Rate	longitude	latitude
15	Meghalaya	4.55	1311125.71	58.31	25.47	91.37
22	Telangana	6.97	15809135.29	53.42	18.11	79.02
23	Tripura	22.79	1338411.86	53.31	23.94	91.99
26	West Bengal	11.88	32051822.71	44.17	22.99	87.86
6	Gujarat	6.45	22122382.71	44.08	22.26	71.19

plt.figure(figsize=(25,8))


plt.subplot(1,2,1)
plt.title("Estimated_Labour_Participation_Rate Before Lockdown",fontsize=16)
sns.barplot(data=Estimated_Labour_Participation_Rate1,x="States",y="Estimated Labour Participation Rate")
plt.xticks(rotation= 90)
plt.xlabel('States',fontsize=16)
plt.ylabel('Estimated_Labour_Participation_Rate2',fontsize=16)


plt.subplot(1,2,2)
plt.title("Estimated_Labour_Participation_Rate During Lockdown",fontsize=16)
sns.barplot(data=Estimated_Labour_Participation_Rate2,x="States",y="Estimated Labour Participation Rate")
plt.xticks(rotation= 90)
plt.xlabel('States',fontsize=16)
plt.ylabel('Estimated_Labour_Participation_Rate',fontsize=16)


plt.show()
     

Top Five State Were Maximum Estimated Labour Participation Rate Before Lockdown

Tripura 64.53
Meghalaya 58.43
Telangana 55.01
Sikkim 48.64
Gujarat 47.91
Top Five State Were Maximum Estimated Labour Participation Rate During Lockdown

Meghalaya 58.31
Telangana 53.42
Tripura 53.31
West Bengal 44.17
Gujarat 44.08
Thank You

        -NAVJOT KHATRI
